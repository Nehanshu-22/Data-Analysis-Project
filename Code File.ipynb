# %%
#Weather data analysis
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

file_data=pd.read_csv("weatherHistory.csv")
file_data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
file_data[["Date-Time","Time_Zone"]]=file_data["Formatted Date"].str.split("+",expand=True)
df1=file_data.drop(columns="Formatted Date")
df1.head()

# Changing the order of the columns
columns_order=["Date-Time","Time_Zone","Summary","Precip Type","Temperature (C)","Apparent Temperature (C)",
                "Humidity","Wind Speed (km/h)","Wind Bearing (degrees)","Visibility (km)","CLoud Cover",
                "Pressure (millibars)", "Daily Summary"]
df2=file_data.reindex(columns=columns_order)
df3=df2.drop(columns="Time_Zone")
df3.head()
# Out:
#                   Date-Time        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000   Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000   Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000   Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000   Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000   Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  CLoud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263          0.0               1015.13
# ...

# %%
#Data Exploration
df3.head()
# Out:
#                   Date-Time        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000   Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000   Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000   Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000   Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000   Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  CLoud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263          0.0               1015.13
# ...

# %%
df3.tail()
# Out:
#                       Date-Time        Summary Precip Type  Temperature (C)  \
# 96448  2016-09-09 19:00:00.000   Partly Cloudy        rain        26.016667
# 96449  2016-09-09 20:00:00.000   Partly Cloudy        rain        24.583333
# 96450  2016-09-09 21:00:00.000   Partly Cloudy        rain        22.038889
# 96451  2016-09-09 22:00:00.000   Partly Cloudy        rain        21.522222
# 96452  2016-09-09 23:00:00.000   Partly Cloudy        rain        20.438889
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448                 26.016667      0.43            10.9963
# 96449                 24.583333      0.48            10.0947
# 96450                 22.038889      0.56             8.9838
# 96451                 21.522222      0.60            10.5294
# 96452                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  CLoud Cover  \
# 96448                    31.0          16.1000          0.0
# ...

# %%
df3.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       96453.000000            96453.000000     96453.000000
# mean           10.810640              187.509232        10.347325
# std             6.913571              107.383428         4.192123
# min             0.000000                0.000000         0.000000
# ...

# %%
df3.info
# Out:
# <bound method DataFrame.info of                       Date-Time        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01 00:00:00.000   Partly Cloudy        rain         9.472222
# 1      2006-04-01 01:00:00.000   Partly Cloudy        rain         9.355556
# 2      2006-04-01 02:00:00.000   Mostly Cloudy        rain         9.377778
# 3      2006-04-01 03:00:00.000   Partly Cloudy        rain         8.288889
# 4      2006-04-01 04:00:00.000   Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448  2016-09-09 19:00:00.000   Partly Cloudy        rain        26.016667
# 96449  2016-09-09 20:00:00.000   Partly Cloudy        rain        24.583333
# 96450  2016-09-09 21:00:00.000   Partly Cloudy        rain        22.038889
# 96451  2016-09-09 22:00:00.000   Partly Cloudy        rain        21.522222
# 96452  2016-09-09 23:00:00.000   Partly Cloudy        rain        20.438889
#
# ...

# %%
df3["Date-Time"]=pd.to_datetime(df3["Date-Time"])
df3["Year"]=pd.DatetimeIndex(df3["Date-Time"]).year
df3["Month"]=df3["Date-Time"].dt.month_name()
df3["day"]=df3["Date-Time"].dt.day
df3.head()
# Out:
#             Date-Time        Summary Precip Type  Temperature (C)  \
# 0 2006-04-01 00:00:00  Partly Cloudy        rain         9.472222
# 1 2006-04-01 01:00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 02:00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 03:00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 04:00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  CLoud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263          0.0               1015.13
# ...

# %%
file_data.shape
# Out:
# (96453, 14)

# %%
#Weather condidtions in numbers
df3['Daily Summary'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
df3['Summary'].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
# Number of times it rained
df3[df3.Summary=='Rain']
# Out:
#                 Date-Time Summary Precip Type  Temperature (C)  \
# 95323 2016-10-21 23:00:00    Rain        rain         9.738889
# 95324 2016-10-22 00:00:00    Rain        rain         9.288889
# 95325 2016-10-22 01:00:00    Rain        rain         8.738889
# 95326 2016-10-22 02:00:00    Rain        rain         8.205556
# 95424 2016-10-26 04:00:00    Rain        rain        10.844444
# 95425 2016-10-26 05:00:00    Rain        rain        10.561111
# 95426 2016-10-26 06:00:00    Rain        rain        10.488889
# 95427 2016-10-26 07:00:00    Rain        rain        10.633333
# 95428 2016-10-26 08:00:00    Rain        rain        10.961111
# 95429 2016-10-26 09:00:00    Rain        rain        11.500000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 95323                  9.738889      0.96             4.2826
# 95324                  8.244444      0.95             7.7280
# 95325                  6.994444      0.95            10.8192
# ...

# %%
# Average Temperature over the last few years

df3['Temperature (C)'].describe()
# Out:
# count    96453.000000
# mean        11.932678
# std          9.551546
# min        -21.822222
# 25%          4.688889
# 50%         12.000000
# 75%         18.838889
# max         39.905556
# Name: Temperature (C), dtype: float64

# %%
Avg_Temp=pd.DataFrame(df3.groupby("Year")["Temperature (C)"].mean())
Avg_Temp
# Out:
#       Temperature (C)
# Year
# 2006        11.215365
# 2007        12.135239
# 2008        12.161876
# 2009        12.267910
# 2010        11.202061
# 2011        11.524453
# 2012        11.986726
# 2013        11.940719
# 2014        12.529737
# 2015        12.311370
# 2016        11.985292

# %%
fig,ax=plt.subplots(figsize=(10,10))
sn.lineplot(x=Avg_Temp.index,y=Avg_Temp["Temperature (C)"])
plt.title("Average Annual Temperature")
# Out:
# Text(0.5, 1.0, 'Average Annual Temperature')

# %%
# Average monthly temperature over the years
Avg_Temp_month=pd.DataFrame(df3.groupby("Month")["Temperature (C)"].mean())
month=["January","February","March","April","May","June","July","August","September","October","November","December"]
Avg_Temp_monthly=Avg_Temp_month.reindex(index=month)
Avg_Temp_monthly
# Out:
#            Temperature (C)
# Month
# January           0.813890
# February          2.159699
# March             6.906599
# April            12.756417
# May              16.873692
# June             20.715617
# July             22.963943
# August           22.345031
# September        17.516790
# October          11.342247
# November          6.589907
# December          1.633742

# %%
fig,ax=plt.subplots(figsize=(10,10))
sn.lineplot(x=Avg_Temp_monthly.index,y=Avg_Temp_monthly["Temperature (C)"])
plt.title("Average Monthly Temperature over the years")
# Out:
# Text(0.5, 1.0, 'Average Monthly Temperature over the years')

# %%
# Monthly Visibility
Avg_Visib_month=pd.DataFrame(df3.groupby("Month")["Visibility (km)"].mean())
month=["January","February","March","April","May","June","July","August","September","October","November","December"]
Avg_Visib_monthly=Avg_Visib_month.reindex(index=month)
Avg_Visib_monthly
# Out:
#            Visibility (km)
# Month
# January           7.830584
# February          8.731368
# March            10.910450
# April            11.784224
# May              11.892754
# June             11.990266
# July             12.187820
# August           12.455549
# September        11.602874
# October           9.741691
# November          8.191229
# December          6.773288

# %%
fig,ax=plt.subplots(figsize=(10,10))
sn.barplot(x=Avg_Visib_monthly.index,y=Avg_Visib_monthly["Visibility (km)"])
plt.title("Average Monthly Visibility over the years")
# Out:
# Text(0.5, 1.0, 'Average Monthly Visibility over the years')

# %%
# Annual Average Wind speed over the years
Avg_Wind_Speed=pd.DataFrame(df3.groupby("Year")["Wind Speed (km/h)"].mean())
Avg_Wind_Speed
# Out:
#       Wind Speed (km/h)
# Year
# 2006          10.189852
# 2007          10.825392
# 2008          11.303897
# 2009          11.505948
# 2010          11.015628
# 2011           9.898262
# 2012          11.264545
# 2013          10.969389
# 2014          10.502473
# 2015          10.735247
# 2016          10.703441

# %%
fig,ax=plt.subplots(figsize=(10,10))
sn.lineplot(data=df3, x ="Year", y="Wind Speed (km/h)")
plt.title("Average Annual Wind Speed over the years")
# Out:
# Text(0.5, 1.0, 'Average Annual Wind Speed over the years')

# %%
# Relationship between Wind Speed and Humidity
fig = plt.figure(figsize=(10,10))
sn.jointplot(x=df3['Wind Speed (km/h)'],y=df3['Humidity'],kind='kde');
plt.savefig("Wind Speed vs Humidty Density Plot")

# %%
# Yearly fluctuations in Humidity
fig = plt.figure(figsize=(10,10))
sn.histplot(data = df3, y='Humidity',x='Year',kde = True,hue="Year",color="")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Humidity'>

# %%
# Daily variations in Air Pressure
fig,ax=plt.subplots(figsize=(10,10))
sn.barplot(data=df3, x ="day", y= "Pressure (millibars)")
plt.title("Daily Variations in Air Pressure")
# Out:
# Text(0.5, 1.0, 'Daily Variations in Air Pressure')

# %%
# Relationship between Wind Speed and Pressure
fig = plt.figure(figsize=(10,10))
sn.jointplot(x=df3['Wind Speed (km/h)'],y=df3['Pressure (millibars)'],kind='kde');
plt.savefig("Wind Speed vs Pressure Density Plot")

# %%
# Correlation between variables
df4=df3.drop(["CLoud Cover","Year","day","Month"],axis=1)
d_corr=df4.corr()
d_corr
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# ...

# %%
# Correlation heat map
fig,ax=plt.subplots(figsize=(10,10))
sn.heatmap(d_corr,annot=True,cmap='magma_r',linewidths=0.2)
plt.title("correlations heat map")
# Out:
# Text(0.5, 1.0, 'correlations heat map')
